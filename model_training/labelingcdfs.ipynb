# %%
import cdflib
import numpy as np
import os

# %%
import spacepy.pycdf as pycdf
from spacepy.pycdf import CDFError

# Path to the data directory
data_dir = r"D:\mms\Data\mms\mms1\fpi\fast\l2\dis-dist\2017\11\labeled"
label_cdf = cdflib.CDF(r"D:\mms\OLSHEVSKY\mmslearning\labels_human\labels_fpi_fast_dis_dist_201711.cdf")

regions = {-1: 'Unknown', 0: 'Solar Wind', 1: 'Foreshock', 2: 'Magnetosheath', 3: 'Magnetosphere'}

# Track corrupted files
corrupted_time_ids = []

# Get all variables from the label CDF
info = label_cdf.cdf_info()
variables = info.zVariables

for var in variables:
    if var[0] == 'l':  # only process label variables
        print(f"\nProcessing variable: {var}")
        time_id = var.split('_')[-1]
        print(f"Time ID: {time_id}")    

        # Extract label array
        label = np.array(label_cdf.varget(var), dtype=np.int8)
        print(f"Label shape: {label.shape}")

        # Find the matching data file
        for file in os.listdir(data_dir):
            if time_id in file:
                filepath = os.path.join(data_dir, file)
                print(f"Found file: {file}")

                try:
                    # Try to open existing CDF in write mode
                    with pycdf.CDF(filepath, readonly=False) as data_cdf:
                        if "label" in data_cdf:
                            print("Variable 'label' already exists, overwriting...")
                            data_cdf["label"][...] = label
                        else:
                            print("Creating new variable 'label'...")
                            data_cdf.new("label", data=label, type=pycdf.const.CDF_INT1)

                        # Set attributes
                        data_cdf["label"].attrs["VAR_NOTES"] = "Predicted label " + str(regions)
                        data_cdf.attrs["filename"] = f"mms1_fpi_fast_l2_dis-dist_{time_id}_v3.4.0.cdf"

                    print(f"✅ Written variable 'label' to file '{file}'")

                except CDFError as e:
                    print(f"❌ Skipping corrupted file: {file} ({e})")
                    corrupted_time_ids.append(time_id)

                break
    elif var[0] == 'e': #process epoch variables
        print(f"\nProcessing epoch variable: {var}")
        time_id = var.split('_')[-1]
        print(f"Time ID: {time_id}")    

        # Extract epoch array
        epoch = np.array(label_cdf.varget(var))
        print(f"Epoch shape: {epoch.shape}")

        # Find the matching data file
        for file in os.listdir(data_dir):
            if time_id in file:
                filepath = os.path.join(data_dir, file)
                print(f"Found file: {file}")

                try:
                    # Try to open existing CDF in write mode
                    with pycdf.CDF(filepath, readonly=False) as data_cdf:
                        print("Creating new variable 'label_epoch'...")
                        if "label_epoch" in data_cdf:
                            print("Variable 'label_epoch' already exists, overwriting...")
                            data_cdf["label_epoch"][...] = epoch
                        else:
                            print("Creating new variable 'label_epoch'...")
                            data_cdf.new("label_epoch", data=epoch, type=pycdf.const.CDF_EPOCH)

                        # Set attributes
                        data_cdf["label_epoch"].attrs["VAR_NOTES"] = "Epoch time variable"
                        data_cdf.attrs["filename"] = f"mms1_fpi_fast_l2_dis-dist_{time_id}_v3.4.0.cdf"

                    print(f"✅ Written variable 'label_epoch' to file '{file}'")

                except CDFError as e:
                    print(f"❌ Skipping corrupted file: {file} ({e})")
                    corrupted_time_ids.append(time_id)

                break
        

# Print summary of corrupted files
if corrupted_time_ids:
    print("\n⚠️ Corrupted files detected:")
    for tid in corrupted_time_ids:
        print(f" - Time ID: {tid}")
else:
    print("\n✅ No corrupted files detected.")
# Out:
# Processing variable: label_mms1_fpi_fast_dis_dist_20171109180000
# Time ID: 20171109180000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171109180000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171109180000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171109180000
# Time ID: 20171109180000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171109180000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171109180000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171102020000
# Time ID: 20171102020000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102020000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171102020000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171102020000
# Time ID: 20171102020000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102020000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171102020000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171104220000
# Time ID: 20171104220000
# Label shape: (1599,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104220000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171104220000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171104220000
# Time ID: 20171104220000
# Epoch shape: (1599,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104220000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171104220000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171108080000
# Time ID: 20171108080000
# Label shape: (1082,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171108080000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171108080000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171108080000
# Time ID: 20171108080000
# Epoch shape: (1082,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171108080000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171108080000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171108120000
# Time ID: 20171108120000
# Label shape: (1383,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171108120000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171108120000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171108120000
# Time ID: 20171108120000
# Epoch shape: (1383,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171108120000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171108120000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171110120000
# Time ID: 20171110120000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171110120000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171110120000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171110120000
# Time ID: 20171110120000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171110120000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171110120000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171110160000
# Time ID: 20171110160000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171110160000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171110160000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171110160000
# Time ID: 20171110160000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171110160000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171110160000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171113020000
# Time ID: 20171113020000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171113020000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171113020000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171113020000
# Time ID: 20171113020000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171113020000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171113020000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171113120000
# Time ID: 20171113120000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171113120000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171113120000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171113120000
# Time ID: 20171113120000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171113120000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171113120000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171104040000
# Time ID: 20171104040000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104040000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171104040000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171104040000
# Time ID: 20171104040000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104040000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171104040000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171109160000
# Time ID: 20171109160000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171109160000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171109160000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171109160000
# Time ID: 20171109160000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171109160000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171109160000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171113080000
# Time ID: 20171113080000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171113080000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171113080000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171113080000
# Time ID: 20171113080000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171113080000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171113080000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171117140000
# Time ID: 20171117140000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171117140000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171117140000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171117140000
# Time ID: 20171117140000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171117140000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171117140000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171117160000
# Time ID: 20171117160000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171117160000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171117160000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171117160000
# Time ID: 20171117160000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171117160000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171117160000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171119080000
# Time ID: 20171119080000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171119080000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171119080000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171119080000
# Time ID: 20171119080000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171119080000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171119080000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171123060000
# Time ID: 20171123060000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171123060000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171123060000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171123060000
# Time ID: 20171123060000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171123060000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171123060000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171128220000
# Time ID: 20171128220000
# Label shape: (1498,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128220000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171128220000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171128220000
# Time ID: 20171128220000
# Epoch shape: (1498,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128220000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171128220000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171101020000
# Time ID: 20171101020000
# Label shape: (468,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101020000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171101020000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171101020000
# Time ID: 20171101020000
# Epoch shape: (468,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101020000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171101020000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171101040000
# Time ID: 20171101040000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101040000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171101040000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171101040000
# Time ID: 20171101040000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101040000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171101040000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171101060000
# Time ID: 20171101060000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101060000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171101060000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171101060000
# Time ID: 20171101060000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101060000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171101060000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171101080000
# Time ID: 20171101080000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101080000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171101080000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171101080000
# Time ID: 20171101080000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101080000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171101080000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171101100000
# Time ID: 20171101100000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101100000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171101100000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171101100000
# Time ID: 20171101100000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101100000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171101100000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171101120000
# Time ID: 20171101120000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101120000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171101120000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171101120000
# Time ID: 20171101120000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101120000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171101120000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171101140000
# Time ID: 20171101140000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101140000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171101140000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171101140000
# Time ID: 20171101140000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101140000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171101140000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171101160000
# Time ID: 20171101160000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101160000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171101160000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171101160000
# Time ID: 20171101160000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101160000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171101160000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171101180000
# Time ID: 20171101180000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101180000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171101180000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171101180000
# Time ID: 20171101180000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101180000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171101180000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171101200000
# Time ID: 20171101200000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101200000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171101200000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171101200000
# Time ID: 20171101200000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101200000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171101200000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171101220000
# Time ID: 20171101220000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101220000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171101220000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171101220000
# Time ID: 20171101220000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171101220000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171101220000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171102000000
# Time ID: 20171102000000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102000000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171102000000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171102000000
# Time ID: 20171102000000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102000000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171102000000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171102040000
# Time ID: 20171102040000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102040000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171102040000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171102040000
# Time ID: 20171102040000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102040000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171102040000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171102060000
# Time ID: 20171102060000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102060000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171102060000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171102060000
# Time ID: 20171102060000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102060000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171102060000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171102080000
# Time ID: 20171102080000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102080000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171102080000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171102080000
# Time ID: 20171102080000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102080000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171102080000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171102100000
# Time ID: 20171102100000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102100000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171102100000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171102100000
# Time ID: 20171102100000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102100000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171102100000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171102120000
# Time ID: 20171102120000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102120000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171102120000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171102120000
# Time ID: 20171102120000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102120000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171102120000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171102140000
# Time ID: 20171102140000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102140000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171102140000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171102140000
# Time ID: 20171102140000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102140000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171102140000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171102160000
# Time ID: 20171102160000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102160000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171102160000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171102160000
# Time ID: 20171102160000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102160000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171102160000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171102180000
# Time ID: 20171102180000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102180000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171102180000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171102180000
# Time ID: 20171102180000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102180000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171102180000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171102200000
# Time ID: 20171102200000
# Label shape: (1117,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102200000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171102200000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171102200000
# Time ID: 20171102200000
# Epoch shape: (1117,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171102200000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171102200000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171103220000
# Time ID: 20171103220000
# Label shape: (338,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171103220000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171103220000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171103220000
# Time ID: 20171103220000
# Epoch shape: (338,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171103220000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171103220000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171104000000
# Time ID: 20171104000000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104000000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171104000000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171104000000
# Time ID: 20171104000000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104000000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171104000000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171104020000
# Time ID: 20171104020000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104020000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171104020000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171104020000
# Time ID: 20171104020000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104020000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171104020000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171104060000
# Time ID: 20171104060000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104060000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171104060000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171104060000
# Time ID: 20171104060000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104060000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171104060000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171104080000
# Time ID: 20171104080000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104080000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171104080000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171104080000
# Time ID: 20171104080000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104080000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171104080000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171104100000
# Time ID: 20171104100000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104100000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171104100000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171104100000
# Time ID: 20171104100000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104100000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171104100000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171104120000
# Time ID: 20171104120000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104120000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171104120000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171104120000
# Time ID: 20171104120000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104120000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171104120000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171104140000
# Time ID: 20171104140000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104140000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171104140000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171104140000
# Time ID: 20171104140000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104140000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171104140000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171104160000
# Time ID: 20171104160000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104160000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171104160000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171104160000
# Time ID: 20171104160000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104160000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171104160000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171104180000
# Time ID: 20171104180000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104180000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171104180000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171104180000
# Time ID: 20171104180000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104180000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171104180000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171104200000
# Time ID: 20171104200000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104200000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171104200000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171104200000
# Time ID: 20171104200000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171104200000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171104200000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171105000000
# Time ID: 20171105000000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105000000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171105000000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171105000000
# Time ID: 20171105000000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105000000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171105000000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171105020000
# Time ID: 20171105020000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105020000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171105020000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171105020000
# Time ID: 20171105020000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105020000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171105020000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171105040000
# Time ID: 20171105040000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105040000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171105040000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171105040000
# Time ID: 20171105040000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105040000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171105040000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171105060000
# Time ID: 20171105060000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105060000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171105060000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171105060000
# Time ID: 20171105060000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105060000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171105060000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171105080000
# Time ID: 20171105080000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105080000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171105080000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171105080000
# Time ID: 20171105080000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105080000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171105080000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171105100000
# Time ID: 20171105100000
# Label shape: (1599,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105100000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171105100000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171105100000
# Time ID: 20171105100000
# Epoch shape: (1599,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105100000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171105100000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171105120000
# Time ID: 20171105120000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105120000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171105120000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171105120000
# Time ID: 20171105120000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105120000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171105120000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171105140000
# Time ID: 20171105140000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105140000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171105140000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171105140000
# Time ID: 20171105140000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105140000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171105140000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171105160000
# Time ID: 20171105160000
# Label shape: (1251,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105160000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171105160000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171105160000
# Time ID: 20171105160000
# Epoch shape: (1251,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171105160000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171105160000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171106180000
# Time ID: 20171106180000
# Label shape: (204,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171106180000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171106180000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171106180000
# Time ID: 20171106180000
# Epoch shape: (204,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171106180000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171106180000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171106200000
# Time ID: 20171106200000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171106200000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171106200000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171106200000
# Time ID: 20171106200000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171106200000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171106200000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171106220000
# Time ID: 20171106220000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171106220000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171106220000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171106220000
# Time ID: 20171106220000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171106220000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171106220000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171107000000
# Time ID: 20171107000000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107000000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171107000000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171107000000
# Time ID: 20171107000000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107000000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171107000000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171107020000
# Time ID: 20171107020000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107020000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171107020000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171107020000
# Time ID: 20171107020000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107020000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171107020000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171107040000
# Time ID: 20171107040000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107040000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171107040000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171107040000
# Time ID: 20171107040000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107040000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171107040000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171107060000
# Time ID: 20171107060000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107060000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171107060000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171107060000
# Time ID: 20171107060000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107060000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171107060000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171107080000
# Time ID: 20171107080000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107080000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171107080000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171107080000
# Time ID: 20171107080000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107080000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171107080000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171107100000
# Time ID: 20171107100000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107100000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171107100000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171107100000
# Time ID: 20171107100000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107100000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171107100000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171107120000
# Time ID: 20171107120000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107120000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171107120000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171107120000
# Time ID: 20171107120000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107120000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171107120000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171107140000
# Time ID: 20171107140000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107140000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171107140000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171107140000
# Time ID: 20171107140000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107140000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171107140000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171107160000
# Time ID: 20171107160000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107160000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171107160000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171107160000
# Time ID: 20171107160000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107160000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171107160000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171107180000
# Time ID: 20171107180000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107180000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171107180000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171107180000
# Time ID: 20171107180000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107180000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171107180000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171107200000
# Time ID: 20171107200000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107200000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171107200000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171107200000
# Time ID: 20171107200000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171107200000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171107200000_v3.4.0.cdf'
#
# ...
# Time ID: 20171125220000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171125220000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171125220000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171125220000
# Time ID: 20171125220000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171125220000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171125220000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171126000000
# Time ID: 20171126000000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171126000000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171126000000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171126000000
# Time ID: 20171126000000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171126000000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171126000000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171126020000
# Time ID: 20171126020000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171126020000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171126020000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171126020000
# Time ID: 20171126020000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171126020000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171126020000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171126040000
# Time ID: 20171126040000
# Label shape: (445,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171126040000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171126040000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171126040000
# Time ID: 20171126040000
# Epoch shape: (445,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171126040000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171126040000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171126180000
# Time ID: 20171126180000
# Label shape: (899,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171126180000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171126180000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171126180000
# Time ID: 20171126180000
# Epoch shape: (899,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171126180000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171126180000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171126200000
# Time ID: 20171126200000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171126200000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171126200000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171126200000
# Time ID: 20171126200000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171126200000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171126200000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171126220000
# Time ID: 20171126220000
# Label shape: (1032,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171126220000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171126220000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171126220000
# Time ID: 20171126220000
# Epoch shape: (1032,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171126220000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171126220000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171127180000
# Time ID: 20171127180000
# Label shape: (619,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171127180000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171127180000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171127180000
# Time ID: 20171127180000
# Epoch shape: (619,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171127180000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171127180000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171127200000
# Time ID: 20171127200000
# Label shape: (1599,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171127200000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171127200000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171127200000
# Time ID: 20171127200000
# Epoch shape: (1599,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171127200000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171127200000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171127220000
# Time ID: 20171127220000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171127220000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171127220000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171127220000
# Time ID: 20171127220000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171127220000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171127220000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171128000000
# Time ID: 20171128000000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128000000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171128000000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171128000000
# Time ID: 20171128000000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128000000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171128000000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171128020000
# Time ID: 20171128020000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128020000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171128020000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171128020000
# Time ID: 20171128020000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128020000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171128020000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171128040000
# Time ID: 20171128040000
# Label shape: (732,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128040000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171128040000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171128040000
# Time ID: 20171128040000
# Epoch shape: (732,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128040000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171128040000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171128140000
# Time ID: 20171128140000
# Label shape: (1272,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128140000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171128140000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171128140000
# Time ID: 20171128140000
# Epoch shape: (1272,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128140000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171128140000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171128160000
# Time ID: 20171128160000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128160000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171128160000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171128160000
# Time ID: 20171128160000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128160000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171128160000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171128180000
# Time ID: 20171128180000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128180000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171128180000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171128180000
# Time ID: 20171128180000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128180000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171128180000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171128200000
# Time ID: 20171128200000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128200000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171128200000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171128200000
# Time ID: 20171128200000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171128200000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171128200000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171129140000
# Time ID: 20171129140000
# Label shape: (675,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171129140000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171129140000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171129140000
# Time ID: 20171129140000
# Epoch shape: (675,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171129140000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171129140000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171129160000
# Time ID: 20171129160000
# Label shape: (1552,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171129160000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171129160000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171129160000
# Time ID: 20171129160000
# Epoch shape: (1552,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171129160000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171129160000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171130140000
# Time ID: 20171130140000
# Label shape: (608,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171130140000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171130140000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171130140000
# Time ID: 20171130140000
# Epoch shape: (608,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171130140000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171130140000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171130160000
# Time ID: 20171130160000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171130160000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171130160000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171130160000
# Time ID: 20171130160000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171130160000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171130160000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171130180000
# Time ID: 20171130180000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171130180000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171130180000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171130180000
# Time ID: 20171130180000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171130180000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171130180000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171130200000
# Time ID: 20171130200000
# Label shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171130200000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171130200000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171130200000
# Time ID: 20171130200000
# Epoch shape: (1600,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171130200000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171130200000_v3.4.0.cdf'
#
# Processing variable: label_mms1_fpi_fast_dis_dist_20171130220000
# Time ID: 20171130220000
# Label shape: (1599,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171130220000_v3.4.0.cdf
# Variable 'label' already exists, overwriting...
# ✅ Written variable 'label' to file 'mms1_fpi_fast_l2_dis-dist_20171130220000_v3.4.0.cdf'
#
# Processing epoch variable: epoch_mms1_fpi_fast_dis_dist_20171130220000
# Time ID: 20171130220000
# Epoch shape: (1599,)
# Found file: mms1_fpi_fast_l2_dis-dist_20171130220000_v3.4.0.cdf
# Creating new variable 'label_epoch'...
# Creating new variable 'label_epoch'...
# ✅ Written variable 'label_epoch' to file 'mms1_fpi_fast_l2_dis-dist_20171130220000_v3.4.0.cdf'
#
# ✅ No corrupted files detected.
